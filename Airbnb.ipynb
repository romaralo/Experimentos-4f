# %% [markdown]
# <a href="https://colab.research.google.com/github/romaralo/Experimentos-4f/blob/main/Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

# %%
db=pd.read_excel("/content/drive/MyDrive/listings.xls.csv.xlsx")

# %%
df = pd.read_csv("/content/drive/MyDrive/listings_detailed_filtered.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-7-d8f7ea253a88> in <cell line: 1>()
# ----> 1 df = pd.read_csv("/content/drive/MyDrive/listings_detailed_filtered.csv")
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     with parser:
# --> 611         return parser.read(nrows)
#     612
#     613
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1776                     columns,
#    1777                     col_dict,
# -> 1778                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1779                     nrows
#    1780                 )
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     228         try:
#     229             if self.low_memory:
# --> 230                 chunks = self._reader.read_low_memory(nrows)
#     231                 # destructive to chunks
#     232                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: EOF inside string starting at row 893

# %%
#cargamos bbdd como panda
db.head(7)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   6369   https://www.airbnb.com/rooms/6369  20230315024316   2023-03-15
# 1  21853  https://www.airbnb.com/rooms/21853  20230315024316   2023-03-15
# 2  24805  https://www.airbnb.com/rooms/24805  20230315024316   2023-03-15
# 3  26825  https://www.airbnb.com/rooms/26825  20230315024316   2023-03-15
# 4  30320  https://www.airbnb.com/rooms/30320  20230315024316   2023-03-15
# 5  30959  https://www.airbnb.com/rooms/30959  20230315024316   2023-03-15
# 6  40718  https://www.airbnb.com/rooms/40718  20230315024316   2023-03-15
#
#             source                                               name  \
# 0      city scrape           Rooftop terrace room ,  ensuite bathroom
# 1      city scrape                               Bright and airy room
# 2      city scrape                             Gran Via Studio Madrid
# 3      city scrape                 Single Room whith private Bathroom
# 4      city scrape                        Great Vacational Apartments
# 5  previous scrape                    Beautiful loft in Madrid Center
# 6      city scrape  COZY APARTMENT CIBELES-GRAN VIA-PTA DEL SOL-CH...
#
#                                          description  \
# 0  Excellent connection with the AIRPORT and EXHI...
# 1  We have a quiet and sunny room with a good vie...
# 2  Studio located 50 meters from Gran Via, next t...
# 3  Nice and cozy roon for one person with a priva...
# 4  <b>The space</b><br />Fully furnished spacious...
# 5  Beautiful Loft 60m2 size just in the historica...
# 6  <b>The space</b><br />Apartment, 1 Bedroom + O...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  We live in a leafy neighbourhood with plenty o...
# 2  The area is next to the Gran Via, so people li...
# 3  Es un barrio muy tranquilo, en una zona de Mad...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#                                          picture_url    host_id  ...  \
# 0  https://a0.muscache.com/pictures/683224/4cc318...      13660  ...
# 1  https://a0.muscache.com/pictures/68483181/87bc...      83531  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...  346366726  ...
# 3  https://a0.muscache.com/pictures/149358/218d5b...     114340  ...
# 4  https://a0.muscache.com/pictures/336868/f67409...     130907  ...
# 5  https://a0.muscache.com/pictures/78173471/835e...     132883  ...
# 6  https://a0.muscache.com/pictures/99a841d9-e992...   34217435  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.86                   4.83                4.86
# 1                        4.82                   4.21                4.67
# 2                        4.88                   4.96                4.69
# 3                        4.71                   4.73                4.75
# 4                        4.78                   4.90                4.69
# 5                        4.63                   4.88                4.25
# 6                        4.85                   4.95                4.65
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                f                              2
# 2     NaN                f                              1
# 3     NaN                f                              1
# 4     NaN                f                              3
# 5     NaN                f                              1
# 6     NaN                t                             10
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            3
# 5                                            1
# 6                                           10
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             2
# 2                                             0
# 3                                             1
# 4                                             0
# 5                                             0
# 6                                             0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.64
# 1                                           0              0.32
# 2                                           0              0.26
# 3                                           0              1.18
# 4                                           0              1.11
# 5                                           0              0.08
# 6                                           0              0.86
#
# [7 rows x 75 columns]

# %%
#concer la info de las columnas de mi bbdd
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21239 entries, 0 to 21238
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            21239 non-null  int64
#  1   listing_url                                   21239 non-null  object
#  2   scrape_id                                     21239 non-null  int64
#  3   last_scraped                                  21239 non-null  datetime64[ns]
#  4   source                                        21239 non-null  object
#  5   name                                          21234 non-null  object
#  6   description                                   20621 non-null  object
#  7   neighborhood_overview                         11764 non-null  object
#  8   picture_url                                   21238 non-null  object
#  9   host_id                                       21239 non-null  int64
#  10  host_url                                      21239 non-null  object
#  11  host_name                                     21236 non-null  object
#  12  host_since                                    21236 non-null  datetime64[ns]
#  13  host_location                                 15335 non-null  object
#  14  host_about                                    10233 non-null  object
#  15  host_response_time                            16182 non-null  object
#  16  host_response_rate                            16182 non-null  float64
#  17  host_acceptance_rate                          17070 non-null  float64
#  18  host_is_superhost                             21235 non-null  object
#  19  host_thumbnail_url                            21236 non-null  object
#  20  host_picture_url                              21236 non-null  object
#  21  host_neighbourhood                            10229 non-null  object
#  22  host_listings_count                           21236 non-null  float64
#  23  host_total_listings_count                     21236 non-null  float64
#  24  host_verifications                            21239 non-null  object
#  25  host_has_profile_pic                          21236 non-null  object
#  26  host_identity_verified                        21236 non-null  object
#  27  neighbourhood                                 11764 non-null  object
#  28  neighbourhood_cleansed                        21239 non-null  object
#  29  neighbourhood_group_cleansed                  21239 non-null  object
#  30  latitude                                      21239 non-null  float64
#  31  longitude                                     21239 non-null  float64
#  32  property_type                                 21239 non-null  object
#  33  room_type                                     21239 non-null  object
#  34  accommodates                                  21239 non-null  int64
#  35  bathrooms                                     0 non-null      float64
#  36  bathrooms_text                                21220 non-null  object
#  37  bedrooms                                      19667 non-null  float64
#  38  beds                                          20936 non-null  float64
#  39  amenities                                     21239 non-null  object
#  40  price                                         21239 non-null  object
#  41  minimum_nights                                21239 non-null  int64
#  42  maximum_nights                                21239 non-null  int64
#  43  minimum_minimum_nights                        21239 non-null  int64
#  44  maximum_minimum_nights                        21239 non-null  int64
#  45  minimum_maximum_nights                        21239 non-null  int64
#  46  maximum_maximum_nights                        21239 non-null  int64
#  47  minimum_nights_avg_ntm                        21239 non-null  float64
#  48  maximum_nights_avg_ntm                        21239 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              21239 non-null  object
#  51  availability_30                               21239 non-null  int64
#  52  availability_60                               21239 non-null  int64
#  53  availability_90                               21239 non-null  int64
#  54  availability_365                              21239 non-null  int64
#  55  calendar_last_scraped                         21239 non-null  datetime64[ns]
#  56  number_of_reviews                             21239 non-null  int64
#  57  number_of_reviews_ltm                         21239 non-null  int64
#  58  number_of_reviews_l30d                        21239 non-null  int64
#  59  first_review                                  17168 non-null  datetime64[ns]
#  60  last_review                                   17168 non-null  datetime64[ns]
#  61  review_scores_rating                          17168 non-null  float64
#  62  review_scores_accuracy                        17028 non-null  float64
#  63  review_scores_cleanliness                     17030 non-null  float64
#  64  review_scores_checkin                         17029 non-null  float64
#  65  review_scores_communication                   17028 non-null  float64
#  66  review_scores_location                        17026 non-null  float64
#  67  review_scores_value                           17025 non-null  float64
#  68  license                                       2745 non-null   object
#  69  instant_bookable                              21239 non-null  object
#  70  calculated_host_listings_count                21239 non-null  int64
#  71  calculated_host_listings_count_entire_homes   21239 non-null  int64
#  72  calculated_host_listings_count_private_rooms  21239 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   21239 non-null  int64
#  74  reviews_per_month                             17168 non-null  float64
# dtypes: datetime64[ns](5), float64(20), int64(21), object(29)
# memory usage: 12.2+ MB

# %%
#convertimos el type a datatime
db['last_review'] = pd.to_datetime(db['last_review'])

# %%
condition1=(db['review_scores_rating'] >= 4.8 ) 
condition2=(db['reviews_per_month'] >=1.0)
condition3=(db['last_review'] >= '2022-01-01')


# Seleccionamos las filas que cumplen la condición

df = db.loc[condition1 & condition2 & condition3]

#reviso para ver si lo está haciendo bien

df_tres_columnas = df[['review_scores_rating', 'reviews_per_month', 'last_review']]
df_tres_columnas.head(50)
# Out:
#      review_scores_rating  reviews_per_month last_review
# 14                   4.81               1.27  2023-01-28
# 15                   4.82               1.59  2023-02-27
# 38                   4.92               3.72  2023-03-13
# 47                   4.90               4.55  2023-03-05
# 57                   4.94               1.28  2023-03-13
# 60                   4.85               2.56  2023-03-13
# 61                   4.87               2.26  2023-02-14
# 66                   4.89               1.24  2023-02-27
# 67                   4.87               1.90  2023-02-24
# 69                   4.87               3.96  2023-03-14
# 74                   4.90               1.82  2023-02-13
# 75                   4.93               2.18  2023-01-22
# 93                   4.94               1.18  2023-03-07
# 94                   4.84               2.00  2023-02-27
# 100                  4.87               1.09  2023-02-27
# 113                  4.86               1.72  2023-03-13
# 122                  4.91               4.11  2023-02-26
# 143                  4.87               3.28  2023-03-06
# 144                  4.80               1.05  2023-02-20
# 159                  4.81               1.80  2023-03-05
# 166                  4.97               1.61  2023-03-12
# 168                  4.88               1.01  2022-12-28
# 176                  4.88               1.38  2023-02-22
# 177                  4.94               1.42  2023-01-05
# 179                  4.82               5.19  2023-03-14
# 180                  4.87               1.55  2022-10-02
# 183                  4.89               1.52  2023-02-21
# 220                  4.90               2.58  2023-02-28
# 225                  4.95               1.26  2023-03-11
# 237                  4.81               1.62  2023-02-28
# 239                  4.87               3.97  2023-02-28
# 244                  4.82               2.60  2023-03-04
# 245                  4.90               3.65  2023-03-12
# 248                  4.85               2.74  2023-02-24
# 259                  4.91               3.89  2023-03-12
# 263                  4.93               1.09  2023-03-08
# 265                  4.88               2.29  2023-02-26
# 271                  4.81               1.48  2023-03-02
# 272                  4.84               1.92  2023-03-10
# 284                  4.91               1.72  2023-03-14
# 285                  4.83               1.55  2023-03-12
# 291                  4.91               6.12  2023-03-12
# 295                  4.84               1.30  2022-05-30
# 309                  4.81               1.21  2023-03-06
# 326                  4.83               3.01  2023-02-19
# 329                  4.81               2.83  2023-02-25
# 334                  4.80               1.43  2023-02-27
# 349                  4.90               2.95  2023-02-27
# 350                  4.80               1.26  2023-01-01
# 358                  4.90               3.22  2023-03-12

# %%
import numpy as np

#si la estancia min es menor o iual a 6 entonces la estancia media es 6. else round(8+1,33*estancia_min). La estancia media no puede ser mayor de 365 (si sale mayor =365) --> ninimum_nights

df['mean_nights'] = np.where(df['minimum_nights'] <= 6, 6, round(8 + 1.33 * df['minimum_nights'])) #ver como funciona

df['mean_nights']=np.where(df['minimum_nights'] >365,365,df['minimum_nights'])
# Out:
# <ipython-input-12-9140f6fb69b4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_nights'] = np.where(df['minimum_nights'] <= 6, 6, round(8 + 1.33 * df['minimum_nights'])) #ver como funciona
# <ipython-input-12-9140f6fb69b4>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mean_nights']=np.where(df['minimum_nights'] >365,365,df['minimum_nights'])

# %%
#comprobación
df['mean_nights'].unique()
# Out:
# array([  4,   3,   2,   6,   7,   1,  25,   5,  14,  10,  28,  30, 120,
#         21,  20, 100,  15,  90,   8,  73, 109, 170, 365,  29,  56,  80,
#         31,  32,   9,  18,  35,  23])

# %%
#nueva columna: ocupacion
df['ocupation']=df['mean_nights']*df['number_of_reviews_ltm']

df['ocupation']=np.where(df['ocupation'] >365,365,df['ocupation']) #no mayor de 365
# Out:
# <ipython-input-14-532c75f74d7f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ocupation']=df['mean_nights']*df['number_of_reviews_ltm']
# <ipython-input-14-532c75f74d7f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ocupation']=np.where(df['ocupation'] >365,365,df['ocupation']) #no mayor de 365

# %%
#comprobación
df['ocupation'].unique()
# Out:
# array([112,  54, 124, 108,  60, 138, 104,  75, 119, 141,  50,  58, 126,
#        102,  84,  52, 114,  63,  88, 144, 125,  42, 110, 156,   4,  90,
#        159, 200, 150, 129, 120,  87,  98, 168,  93,  30,  94,  48,  23,
#         92,  32,  68, 195,  36,  22,  24,  34, 147,  12,  70,  69,  73,
#        188,  15, 111,  27, 213,   6,   2,  45, 116, 162, 176, 180, 107,
#        148,  47, 212,  51,  78, 145,  56, 236,  40,  86,  95, 109, 164,
#         16,  72,  43,  53,  26, 118,  96,   3,  55,  62,   9, 105, 136,
#        336, 174,  74,  35, 205, 184,  76, 158,  66,  80, 154, 189,  44,
#         18, 135,  14,  57, 100,  38, 152, 142,  82, 153, 134,  46, 365,
#        246, 196, 140, 117, 146, 122, 249,   8, 132, 252, 115, 183,  49,
#         77,  33,   5, 216, 192,  37,  28, 160, 230, 128, 171,  61,  10,
#          0, 198,  81, 172, 173,  20, 201, 240, 165, 190,  85, 103,  25,
#         71, 210,  31,  67,  64,  21, 106, 130,   7, 182, 330, 101, 123,
#        264, 231, 204, 121, 194,  59,  19,  41, 258, 178,  39, 170, 320,
#        261, 166,  29, 185,  17,  11,  13, 275, 207, 327, 272,   1, 260,
#         65, 222, 300, 225, 228,  99, 151, 155, 177, 238, 186, 175, 234,
#         83,  79, 305, 220, 202,  91, 237,  89, 113, 324, 161, 248, 279])

# %%
df[['mean_nights', 'ocupation']].describe()
# Out:
#        mean_nights    ocupation
# count  3542.000000  3542.000000
# mean      3.106719    62.638340
# std       8.782181    62.080092
# min       1.000000     0.000000
# 25%       1.000000    16.000000
# 50%       2.000000    44.000000
# 75%       3.000000    94.000000
# max     365.000000   365.000000

# %%
db_sorted = df.sort_values(by='ocupation', ascending=False) # quedarme con los mil primeros que mas ocupen 

db_more_ocupation=db_sorted.head(1000)

# %%
db_more_ocupation
# Out:
#                        id                                      listing_url  \
# 2420             14275773            https://www.airbnb.com/rooms/14275773
# 10641            43542587            https://www.airbnb.com/rooms/43542587
# 11336            45605248            https://www.airbnb.com/rooms/45605248
# 1581              9639977             https://www.airbnb.com/rooms/9639977
# 1563              9575680             https://www.airbnb.com/rooms/9575680
# ...                   ...                                              ...
# 18061  731592504127479040  https://www.airbnb.com/rooms/731592504127479605
# 14324  549853577509750016  https://www.airbnb.com/rooms/549853577509750470
# 13374            51759127            https://www.airbnb.com/rooms/51759127
# 14229  539027970030412992  https://www.airbnb.com/rooms/539027970030413902
# 17231  688831380702013952  https://www.airbnb.com/rooms/688831380702014226
#
#             scrape_id last_scraped       source  \
# 2420   20230315024316   2023-03-15  city scrape
# 10641  20230315024316   2023-03-15  city scrape
# 11336  20230315024316   2023-03-15  city scrape
# 1581   20230315024316   2023-03-15  city scrape
# 1563   20230315024316   2023-03-15  city scrape
# ...               ...          ...          ...
# 18061  20230315024316   2023-03-15  city scrape
# 14324  20230315024316   2023-03-15  city scrape
# 13374  20230315024316   2023-03-15  city scrape
# 14229  20230315024316   2023-03-15  city scrape
# 17231  20230315024316   2023-03-15  city scrape
#
#                                                     name  \
# 2420             Charming (perfectly situated) apartment
# 10641  Walk to Subway â˜… Super location â˜… Clean an...
# 11336       Magnifica habitaciÃ³n para disfrutar Madrid.
# 1581                 LATINA BRICK 2br 2ba Cen LIFT WIFI!
# 1563   STUNNING Boutique Studio in CENTER LETRAS WIFI&AC
# ...                                                  ...
# 18061         HabitaciÃ³n con baÃ±o privado en MalasaÃ±a
# 14324   CÃ³moda e impecable  habitaciÃ³n en hermoso piso
# 13374           Beautiful Renovated Loft in the center 9
# 14229  Luxury Apartamento de 5 hab en el centro de Ma...
# 17231     Acogedor y luminoso piso con piscina en Madrid
#
#                                              description  \
# 2420   The apartment is perfectly located(5 minutes w...
# 10641  Beautiful, renovated, and modern studio for sh...
# 11336  La habitaciÃ³n es muy acogedora y luminosa con...
# 1581   UNBEATABLE LOCATION !!!! BEST TAPAS AREA!!! FR...
# 1563   Welcome to our new gorgeous boutique studio!. ...
# ...                                                  ...
# 18061  Disfruta de la tranquilidad de este alojamient...
# 14324  Disfruta de una cÃ³moda habitaciÃ³n en hermoso...
# 13374  Spectacular renovated loft with rustic style i...
# 14229  Amazing 5 bedroom apartment in the heart of Ma...
# 17231  Disconnect in a quiet apartment, decorated wit...
#
#                                    neighborhood_overview  \
# 2420   The apartment is really nice, but the best thi...
# 10641  Quevedo subway station is 1 minute walking<br ...
# 11336  El barrio es una zona tranquila y muy bien com...
# 1581   LA LATINA<br /><br />It is the oldest part of ...
# 1563   Barrio de Las Huertas is one of the prettiest ...
# ...                                                  ...
# 18061  MalaÃ±asa es uno de esos barrios de Madrid car...
# 14324                                                NaN
# 13374  Located in the heart of one of the most fashio...
# 14229  An unbeatable choice to enjoy Madrid<br /><br ...
# 17231  The periphery is also Madrid, but with a much ...
#
#                                              picture_url    host_id  ...  \
# 2420   https://a0.muscache.com/pictures/bd36916d-2bd1...   86307067  ...
# 10641  https://a0.muscache.com/pictures/miso/Hosting-...   47584294  ...
# 11336  https://a0.muscache.com/pictures/35e8312c-09ef...  101614723  ...
# 1581   https://a0.muscache.com/pictures/fe99dcb9-9e5d...    8647044  ...
# 1563   https://a0.muscache.com/pictures/5e7f9cb8-36b6...   22361249  ...
# ...                                                  ...        ...  ...
# 18061  https://a0.muscache.com/pictures/miso/Hosting-...  105551703  ...
# 14324  https://a0.muscache.com/pictures/miso/Hosting-...   52386302  ...
# 13374  https://a0.muscache.com/pictures/prohost-api/H...  107335103  ...
# 14229  https://a0.muscache.com/pictures/prohost-api/H...   90615844  ...
# 17231  https://a0.muscache.com/pictures/miso/Hosting-...   10765698  ...
#
#       review_scores_value   license instant_bookable  \
# 2420                 4.82       NaN                f
# 10641                4.80       NaN                f
# 11336                4.77       NaN                t
# 1581                 4.83       NaN                f
# 1563                 4.93  VT-11881                f
# ...                   ...       ...              ...
# 18061                4.77       NaN                t
# 14324                4.91       NaN                f
# 13374                4.74       NaN                t
# 14229                4.85       NaN                t
# 17231                4.94       NaN                f
#
#       calculated_host_listings_count  \
# 2420                               1
# 10641                              2
# 11336                              3
# 1581                               8
# 1563                               3
# ...                              ...
# 18061                              1
# 14324                              3
# 13374                             96
# 14229                             34
# 17231                              1
#
#       calculated_host_listings_count_entire_homes  \
# 2420                                            1
# 10641                                           2
# 11336                                           0
# 1581                                            8
# 1563                                            3
# ...                                           ...
# 18061                                           0
# 14324                                           0
# 13374                                          63
# 14229                                          34
# 17231                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 2420                                             0
# 10641                                            0
# 11336                                            3
# 1581                                             0
# 1563                                             0
# ...                                            ...
# 18061                                            1
# 14324                                            3
# 13374                                           33
# 14229                                            0
# 17231                                            0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 2420                                             0               3.29
# 10641                                            0               1.06
# 11336                                            0               2.51
# 1581                                             0               1.00
# 1563                                             0               1.63
# ...                                            ...                ...
# 18061                                            0               8.16
# 14324                                            0               6.94
# 13374                                            0               6.55
# 14229                                            0               6.69
# 17231                                            0               2.39
#
#       mean_nights ocupation
# 2420           30       365
# 10641          30       365
# 11336          28       365
# 1581           28       365
# 1563          120       365
# ...           ...       ...
# 18061           2        86
# 14324           1        86
# 13374           1        85
# 14229           1        85
# 17231           5        85
#
# [1000 rows x 77 columns]

# %%
#contamos el numero de veces que sale cada amenities dentro de los 1000 
amenities_list = db_more_ocupation['amenities'].apply(lambda x: x.strip('][').split(', '))
all_words = [word for sublist in amenities_list for word in sublist]

conteo_palabras = {}
for palabra in all_words:
    if palabra not in conteo_palabras:
        conteo_palabras[palabra] = 1
    else:
        conteo_palabras[palabra] += 1

# %%
x=[]
y=[]
for key, value in sorted(conteo_palabras.items(), key=lambda item: item[1], reverse=True):
    if value>=600:
      print(key, value)
      x.append(key)
      y.append(value)
# Out:
# "Essentials" 979
# "Dishes and silverware" 955
# "Hair dryer" 950
# "Hangers" 948
# "Kitchen" 948
# "Hot water" 925
# "Iron" 892
# "Cooking basics" 883
# "Wifi" 878
# "Microwave" 867
# "Refrigerator" 828
# "Bed linens" 797
# "Shampoo" 736
# "Heating" 730
# "Long term stays allowed" 612

# %%
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(27,5))
ax.bar(x, y,color='#E18B8B' )
plt.title('Most repated')
plt.xlabel('Amenities')
plt.ylabel('count amenities')

plt.show()

# %%
# Quiero ver los ratings de las más ocupadas, cuál es más importante.

media_scores_rating = db_more_ocupation["review_scores_rating"].mean()
media_scores_accuracy= db_more_ocupation["review_scores_accuracy"].mean()
media_scores_cleanliness = db_more_ocupation["review_scores_cleanliness"].mean()
media_scores_checkin = db_more_ocupation["review_scores_checkin"].mean()
media_scores_communication = db_more_ocupation["review_scores_communication"].mean()
media_scores_location = db_more_ocupation["review_scores_location"].mean()
print("La media de rating, accuracy,cleanliness,checkin,communication,location", media_scores_rating,
      media_scores_accuracy,media_scores_cleanliness,media_scores_checkin,media_scores_communication,
      media_scores_location)
# Out:
# La media de rating, accuracy,cleanliness,checkin,communication,location 4.8884099999999995 4.91309 4.8935900000000006 4.91516 4.935389999999999 4.8935699999999995

# %%
# More_ocupation tiene el filtro de las reviews.
busqueda = db_more_ocupation["review_scores_rating"].between(0,4.75)

if db_more_ocupation["review_scores_rating"].between(0,4.75).any():
    print("Hay valores")
else:
    print("No hay valores")
# Out:
# No hay valores

# %%
# Con ocupación primera con los ratings también
media_ocupation = db_more_ocupation["ocupation"].mean()
print(media_ocupation)
# Out:
# 142.651

# %%
# Aquí calculamos la ocupación de cada una. Para toda la base de datos.

db['mean_nights1'] = np.where(db['minimum_nights'] <= 6, 6, round(8 + 1.33 * db['minimum_nights'])) #ver como funciona

db['mean_nights1']=np.where(db['minimum_nights'] >365,365,db['minimum_nights'])

db['ocupation1']=db['mean_nights1']*db['number_of_reviews_ltm']

db['ocupation1']=np.where(db['ocupation1'] >365,365,db['ocupation1']) #no mayor de 365

db[['mean_nights1', 'ocupation1']].describe()
# Out:
#        mean_nights1    ocupation1
# count  21239.000000  21239.000000
# mean       6.793211     32.002448
# std       24.566307     51.384271
# min        1.000000      0.000000
# 25%        1.000000      0.000000
# 50%        2.000000      9.000000
# 75%        3.000000     42.000000
# max      365.000000    365.000000

# %%
print(len(db['ocupation1']))
# Out:
# 21239

# %%
db_sorted = db.sort_values(by='ocupation1', ascending=False) # quedarme con los mil primeros que mas ocupen 

db_mas_ocu=db_sorted.head(2000)
media = db_mas_ocu["ocupation1"].mean()
print(media)
# Out:
# 158.8535

# %%
media_scores_rating = db_mas_ocu["review_scores_rating"].mean()
media_scores_accuracy= db_mas_ocu["review_scores_accuracy"].mean()
media_scores_cleanliness = db_mas_ocu["review_scores_cleanliness"].mean()
media_scores_checkin = db_mas_ocu["review_scores_checkin"].mean()
media_scores_communication = db_mas_ocu["review_scores_communication"].mean()
media_scores_location = db_mas_ocu["review_scores_location"].mean()
print("La media de rating, accuracy,cleanliness,checkin,communication,location", media_scores_rating,
      media_scores_accuracy,media_scores_cleanliness,media_scores_checkin,media_scores_communication,
      media_scores_location)
# Out:
# La media de rating, accuracy,cleanliness,checkin,communication,location 4.71966 4.786309999999999 4.745685000000001 4.82724 4.839125 4.86113

# %%
# Vemos si hay valores, comprobar si nos hemos equivocado o nope.
busqueda = db_mas_ocu["review_scores_rating"].between(0,4.75)

if db_mas_ocu["review_scores_rating"].between(0,4.75).any():
    print("Hay valores")
else:
    print("No hay valores")
# Out:
# Hay valores

# %%
print(len(db_mas_ocu))
# Out:
# 2000

# %%
media_resp_rate = db_mas_ocu["host_response_rate"].mean()
media_acep_rate= db_mas_ocu["host_acceptance_rate"].mean()

print(media_resp_rate,media_acep_rate)
# Out:
# 0.9853408508457202 0.967946247464503

# %%
# Las tres frases más repetidas en el response rate.
from collections import Counter
import matplotlib.pyplot as plt

# Obtener las frases de la columna y contarlas
frases_contadas = Counter(db_mas_ocu['host_response_time'])

# Obtener las 10 frases más comunes y sus frecuencias
top_frases = frases_contadas.most_common(3)

# Crear una lista de las frases y una lista de sus frecuencias
frases = [frase for frase, frecuencia in top_frases]
frecuencias = [frecuencia for frase, frecuencia in top_frases]

# Crear el gráfico de barras
plt.bar(frases, frecuencias)

# Añadir etiquetas y título
plt.xlabel('Frase')
plt.ylabel('Frecuencia')
plt.title('Las 10 frases más comunes en la columna "host_repsonse_time"')

# Mostrar el gráfico
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Paso 1: Concatenar las frases de la columna "description"
texto = ' '.join(db_mas_ocu['description'].astype(str))

# Paso 2: Dividir la cadena de texto en una lista de palabras
palabras = texto.split()

# Paso 3: Contar las ocurrencias de cada palabra en la lista
palabras_contadas = Counter(palabras)

# Paso 4: Obtener las 10 palabras más comunes y sus frecuencias
top_palabras = palabras_contadas.most_common(10)

# Paso 5: Crear listas de palabras y frecuencias
palabras = [palabra for palabra, frecuencia in top_palabras]
frecuencias = [frecuencia for palabra, frecuencia in top_palabras]

# Paso 6: Crear el gráfico de barras
plt.bar(palabras, frecuencias)
plt.xlabel('Palabra')
plt.ylabel('Frecuencia')
plt.title('Las 10 palabras más comunes en la columna "description"')
plt.show()

# %%
pip install mtranslate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mtranslate in /usr/local/lib/python3.9/dist-packages (1.8)

# %%
# Host_neighbourdhood: info personal no nos interesa yo creo.
from collections import Counter
import matplotlib.pyplot as plt

# Paso 1: Concatenar las frases de la columna "description"
texto = ' '.join(db_mas_ocu['host_neighbourhood'].astype(str))

# Paso 2: Dividir la cadena de texto en una lista de palabras
palabras = texto.split()

# Paso 3: Contar las ocurrencias de cada palabra en la lista
palabras_contadas = Counter(palabras)

# Paso 4: Obtener las 10 palabras más comunes y sus frecuencias
top_palabras = palabras_contadas.most_common(15)

# Paso 5: Crear listas de palabras y frecuencias
palabras = [palabra for palabra, frecuencia in top_palabras]
frecuencias = [frecuencia for palabra, frecuencia in top_palabras]

# Paso 6: Crear el gráfico de barras
plt.figure(figsize=(15, 10))
plt.bar(palabras, frecuencias)
plt.xlabel('Palabra')
plt.ylabel('Frecuencia')
plt.title('Las 10 palabras más comunes en la columna host_neighbourhood')
plt.show()

# %%
# Vamos a contar de estas 2000 que son las más ocupadas, cuántas son de larga estancia.

import matplotlib.pyplot as plt
from collections import Counter

# Contar las ocurrencias de cada valor en la columna "minimum_nights"
ocurrencias = db_mas_ocu["minimum_nights"].value_counts()

# Filtrar los valores mayores que 28
ocurrencias_filtradas = ocurrencias[ocurrencias.index >= 28]

# Obtener las ocurrencias de cada valor en la columna 'minimum_nights'
ocurrencias = db_mas_ocu['minimum_nights'].value_counts()

# Convertir la serie en un objeto Counter
contador = Counter(dict(ocurrencias_filtradas))

#contador = Counter(dict(ocurrencias)).SALE PIE CHART CON LAS QUE MÁS SALEN EN
# GENERAL SIN TENER EN CUENTA LARGAS ESTANCIAS.

# Obtener las 8 ocurrencias más comunes
ocurrencias_filtradas = contador.most_common(8)

labels = [str(valor) for valor, frecuencia in ocurrencias_filtradas]
sizes = [frecuencia for valor, frecuencia in ocurrencias_filtradas]

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

texto = ' '.join(db_mas_ocu['instant_bookable'].astype(str))
palabras = texto.split()

palabras_contadas = Counter(palabras)

top_palabras = palabras_contadas.most_common(7)

palabras = [palabra for palabra, frecuencia in top_palabras]
frecuencias = [frecuencia for palabra, frecuencia in top_palabras]

plt.pie(frecuencias, labels=palabras, autopct='%1.1f%%')
plt.title('Las palabras más comunes en la columna instant bookable')
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

texto = ' '.join(db_mas_ocu['host_is_superhost'].astype(str))
palabras = texto.split()

palabras_contadas = Counter(palabras)

top_palabras = palabras_contadas.most_common(7)

palabras = [palabra for palabra, frecuencia in top_palabras]
frecuencias = [frecuencia for palabra, frecuencia in top_palabras]

plt.pie(frecuencias, labels=palabras, autopct='%1.1f%%')
plt.title('Las palabras más comunes en la columna host is superhost')
plt.show()

# %%
from collections import Counter
import pandas as pd

# Paso 1: Extraer el año de la columna 'host_since'
df = db_mas_ocu
df['year'] = pd.DatetimeIndex(df['host_since']).year

# Paso 2: Contar las ocurrencias de cada año
ocurrencias = Counter(df['year'])

# Paso 3: Obtener los 10 años más comunes y sus frecuencias
top_anios = ocurrencias.most_common(10)

# Paso 4: Crear listas de años y frecuencias
anios = [anios for anios, frecuencia in top_anios]
frecuencias = [frecuencia for anios, frecuencia in top_anios]

# Paso 5: Crear el histograma
plt.figure(figsize=(20, 10))
plt.bar(anios, frecuencias)
plt.xlabel('Año')
plt.ylabel('Frecuencia')
plt.title('Los 10 años más comunes en la columna "host_since"')
plt.show()
# Out:
# <ipython-input-85-bf7d7bbd4da6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = pd.DatetimeIndex(df['host_since']).year

# %%
# Convertir la columna "price" a un valor numérico.

# Eliminar el símbolo de dólar y convertir la columna a tipo numérico.
# No se puede seguir ejecutando porque al tenerlo ya cambiado da errores.
#db_mas_ocu['price'] = db_mas_ocu['price'].str.replace(',', '').str[1:].astype(float)

# Imprimir algunos valores de la columna price
print(db_mas_ocu['price'].head(7))
# Out:
# 11776    105.0
# 15800    143.0
# 6922      18.0
# 16383     71.0
# 12159    100.0
# 16325    138.0
# 14523    141.0
# Name: price, dtype: float64

# %%
# Está un poco raro el histograma, estaría mejor si apareciese el intervalo
# debajo de cada barra.
import matplotlib.pyplot as plt

# Seleccionar la columna "price"
precio = db_mas_ocu["price"]

# Definir los intervalos de los rangos
intervalos = range(0, 300, 50)

# Crear el histograma con los intervalos definidos
plt.hist(precio, bins=intervalos,edgecolor='black')

# Agregar etiquetas al gráfico
plt.xlabel("Precio")
plt.ylabel("Frecuencia")
plt.title("Histograma de precios")

# Mostrar el gráfico
plt.show()
